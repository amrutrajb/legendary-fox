# %% [markdown]
# PYTHON PROGRAMMING ASSIGNMENT
# Coding Exercises
#
#
#
# Exercise 1: Prime Numbers
# Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.
#
#
#
# Exercise 2: Product of Random Numbers
# Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.
#
#
#
# Exercise 3: Squares of Even/Odd Numbers
# Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.
#
#
#
# Exercise 4: Word counter
# write a program to count the number of words in a given text.
# example:
# input_text = "This is a sample text. This text will be used to demonstrate the word counter."
# Expected output:
# 'This': 2
# 'is': 1
# 'a': 1
# 'sample': 1
# 'text.': 1
#
#
#
# Exercise 5: Check for Palindrome
# Write a Python function called is_palindrome that takes a string as input and returns True if the string is a palindrome, and False otherwise. A palindrome is a word, phrase, number, or other sequence of characters that reads the same forward and backward, ignoring spaces, punctuation, and capitalization.
# Example:
# Input: "racecar"
# Expected Output: True
# ________________________________________
# Please complete the coding exercises and answer the theoretical questions. Submit your work in a single Python (.ipynb) file for the coding exercises.Ensure your code is well-commented to explain your logic and approach. Good luck!

# %% [markdown]
# Exercise 1: Prime Numbers Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
def num_prime(x):
    if x <= 1:
        print(x," is not a prime number")
        return

    for i in range(2, int(x**0.5) + 1):
        if x % i == 0:
            print(x," is not a prime number")
            return

    print( x," is a prime number")

# %%
num_prime(25)
# Out:
# 25  is not a prime number

# %%
num_prime(17)
# Out:
# 17  is a prime number

# %% [markdown]
# Exercise 2: Product of Random Numbers Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random
#creating random two numbers
num_1 = random.randint(1, 10)
num_2 = random.randint(1, 10)

# product of two random numbers
product_of_random_number = num_2 * num_1

# Ask the user to calculate the product
print("What is the product of ",num_1,"and", num_2)
user_input = int(input("Enter answer "))

# Check if the user's answer is correct
if product_of_random_number == user_input:
    print("Correct   ans   ")
else:
    print(f"Incorrect. The correct answer is", product_of_random_number)
# Out:
# What is the product of  3 and 3
# Enter answer 6
# Incorrect. The correct answer is 9

# %% [markdown]
# Exercise 3: Squares of Even/Odd Numbers Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
#printing squares of even number between 100 to 200.
even_squares=[]
for i in range(100, 201):
    if i % 2 == 0:
        print("Square of this" ,i,"number is ",i**2)

even_squares
# Out:
# Square of this 100 number is  10000
# Square of this 102 number is  10404
# Square of this 104 number is  10816
# Square of this 106 number is  11236
# Square of this 108 number is  11664
# Square of this 110 number is  12100
# Square of this 112 number is  12544
# Square of this 114 number is  12996
# Square of this 116 number is  13456
# Square of this 118 number is  13924
# Square of this 120 number is  14400
# Square of this 122 number is  14884
# Square of this 124 number is  15376
# Square of this 126 number is  15876
# Square of this 128 number is  16384
# Square of this 130 number is  16900
# Square of this 132 number is  17424
# Square of this 134 number is  17956
# Square of this 136 number is  18496
# Square of this 138 number is  19044
# Square of this 140 number is  19600
# Square of this 142 number is  20164
# Square of this 144 number is  20736
# Square of this 146 number is  21316
# Square of this 148 number is  21904
# Square of this 150 number is  22500
# Square of this 152 number is  23104
# Square of this 154 number is  23716
# Square of this 156 number is  24336
# Square of this 158 number is  24964
# Square of this 160 number is  25600
# Square of this 162 number is  26244
# Square of this 164 number is  26896
# Square of this 166 number is  27556
# Square of this 168 number is  28224
# Square of this 170 number is  28900
# Square of this 172 number is  29584
# Square of this 174 number is  30276
# Square of this 176 number is  30976
# Square of this 178 number is  31684
# Square of this 180 number is  32400
# Square of this 182 number is  33124
# Square of this 184 number is  33856
# Square of this 186 number is  34596
# Square of this 188 number is  35344
# Square of this 190 number is  36100
# Square of this 192 number is  36864
# Square of this 194 number is  37636
# Square of this 196 number is  38416
# Square of this 198 number is  39204
# Square of this 200 number is  40000
# []

# %% [markdown]
# Exercise 4: Word counter write a program to count the number of words in a given text. example: input_text = "This is a sample text. This text will be used to demonstrate the word counter." Expected output: 'This': 2 'is': 1 'a': 1 'sample': 1 'text.': 1

# %%
input_text= "This is a sample text. This text will be used to demonstrate the word counter."

word_count={}
for word in input_text.split():
        word_count[word]=word_count.get(word,0)+1


for word,count in word_count.items():
    print(f"{word}: {count}")
# Out:
# This: 2
# is: 1
# a: 1
# sample: 1
# text.: 1
# text: 1
# will: 1
# be: 1
# used: 1
# to: 1
# demonstrate: 1
# the: 1
# word: 1
# counter.: 1

# %% [markdown]
# Exercise 5: Check for Palindrome Write a Python function called is_palindrome that takes a string as input and returns True if the string is a palindrome, and False otherwise. A palindrome is a word, phrase, number, or other sequence of characters that reads the same forward and backward, ignoring spaces, punctuation, and capitalization. Example: Input: "racecar" Expected Output: True

# %%
def is_palindrome(x):
    x = x.lower().replace(" ", "")
    return x == x[::-1]

# %%
is_palindrome('racecar')
# Out:
# True
